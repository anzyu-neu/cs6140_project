# %% [markdown]
# # Pull Data from past 5 Seasons

# %%
from main import generate_season_stats

# Generate data for each season and store
# seasons = ['2018-19', '2019-20', '2020-21', '2021-22', '2022-23']
# season_dataframes = {season: generate_season_stats(season) for season in seasons}
test_season = generate_season_stats('2022-23')

# %%
test_season.head()
# Out:
#   teamCity_my_player_1  personId_my_player_1 minutes_my_player_1  \
# 0          Los Angeles                203076               35:36
# 1         Golden State                201939               32:48
# 2         Philadelphia               1630178               38:12
# 3               Boston               1628369               38:37
# 4            Cleveland               1630596               35:35
#
#    speed_my_player_1  distance_my_player_1  \
# 0               4.04                  2.57
# 1               4.57                  2.66
# 2               4.44                  3.02
# 3               3.85                  2.66
# 4               4.08                  2.61
#
#    reboundChancesOffensive_my_player_1  reboundChancesTotal_my_player_1  \
# 0                                    7                               13
# 1                                    2                               10
# 2                                    2                                3
# ...

# %%
print(test_season[['GAME_DATE_EST', 'REST_DAYS', 'IS_BACK_TO_BACK', 'DISTANCE', 'REF_BIAS']])
# Out:
#           GAME_DATE_EST  REST_DAYS  IS_BACK_TO_BACK     DISTANCE  REF_BIAS
# 0   2022-10-18T00:00:00         50            False   347.274305      -3.4
# 1   2022-10-18T00:00:00         50            False     0.000000       3.4
# 2   2022-10-18T00:00:00         50            False   270.993314      -1.0
# 3   2022-10-18T00:00:00         50            False     0.000000       1.0
# 4   2022-10-19T00:00:00         50            False   189.731514      -2.4
# 5   2022-10-19T00:00:00         50            False     0.000000       2.4
# 6   2022-10-19T00:00:00         50            False  5059.249316      -2.4
# 7   2022-10-19T00:00:00         50            False     0.000000       2.4
# 8   2022-10-19T00:00:00         50            False  1170.407994      -0.4
# 9   2022-10-19T00:00:00         50            False     0.000000       0.4
# 10  2022-10-19T00:00:00         50            False   492.001882      -1.6
# ...
