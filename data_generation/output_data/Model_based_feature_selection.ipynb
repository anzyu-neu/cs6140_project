# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.linear_model import Lasso

season_22_23 = pd.read_csv('2022-23_data.csv')
season_23_24 = pd.read_csv('2023-24_data.csv')

# %% [markdown]
# ### Data pre-processing

# %%
# Drop rows with na
s22_23 = season_22_23.dropna()
s23_24 = season_23_24.dropna()

# Drop non-numeric columns
s22_23 = s22_23.select_dtypes(include='number')
s23_24 = s23_24.select_dtypes(include='number')

# Drop feature 'WIN'
s22_23 = s22_23.drop(columns=['WON'])
s23_24 = s23_24.drop(columns=['WON'])

# %%
# Split X and y
s22_23_y = s22_23['PTS']
s22_23_X = s22_23.drop(columns=['PTS'])
s23_24_y = s23_24['PTS']
s23_24_X = s23_24.drop(columns=['PTS'])

# %%
# Generate importance df
def get_feature_importance(features, importances):
    importance_df = pd.DataFrame({
        'Feature': features,
        'Importance': importances
    })
    return importance_df.sort_values(by='Importance', ascending=False)

# Filtered features
def filter_features_by_importance(importance_df, top_30_features):
    # Desired features to ensure inclusion
    additional_features = ['REF_BIAS', 'CLOSE_WIN_PCT', 'REST_DAYS', 'IS_BACK_TO_BACK', 'DISTANCE', 'RECENT_WIN_PCT']
    
    combined_features = set(top_30_features) | set(additional_features)
    filtered_df = importance_df[importance_df['Feature'].isin(combined_features)]
    return filtered_df

# %% [markdown]
# ### Random forest regressor

# %%
# season22_23
rf22_23 = RandomForestRegressor(n_estimators=100, random_state=42)
rf22_23.fit(s22_23_X, s22_23_y)

feature_importances = rf22_23.feature_importances_
importance_df = get_feature_importance(s22_23_X.columns, feature_importances)

# %%
top_30_features = set(importance_df.head(30)['Feature'])
filtered_df = filter_features_by_importance(importance_df, top_30_features)
filtered_df
# Out:
#                                          Feature  Importance
# 18               fieldGoalPercentage_my_player_1    0.091964
# 38               fieldGoalPercentage_my_player_2    0.042626
# 78               fieldGoalPercentage_my_player_4    0.038956
# 58               fieldGoalPercentage_my_player_3    0.037627
# 98               fieldGoalPercentage_my_player_5    0.025223
# 118              fieldGoalPercentage_my_player_6    0.022885
# 138              fieldGoalPercentage_my_player_7    0.016619
# 183                      speed_opposing_player_3    0.013345
# 163                      speed_opposing_player_2    0.011931
# 144                   distance_opposing_player_1    0.011512
# 117  uncontestedFieldGoalsPercentage_my_player_6    0.010867
# 37   uncontestedFieldGoalsPercentage_my_player_2    0.009616
# 184                   distance_opposing_player_3    0.009567
# 142                    seconds_opposing_player_1    0.009480
# 77   uncontestedFieldGoalsPercentage_my_player_4    0.009311
# 164                   distance_opposing_player_2    0.008962
# 4                           distance_my_player_1    0.008841
# 223                      speed_opposing_player_5    0.008511
# 203                      speed_opposing_player_4    0.008284
# 57   uncontestedFieldGoalsPercentage_my_player_3    0.008215
# 2                            seconds_my_player_1    0.007987
# 204                   distance_opposing_player_4    0.007936
# 293                             OPPONENT_WIN_PCT    0.007586
# 182                    seconds_opposing_player_3    0.006345
# 24                          distance_my_player_2    0.006228
# 97   uncontestedFieldGoalsPercentage_my_player_5    0.006027
# 43                             speed_my_player_3    0.005936
# 35         uncontestedFieldGoalsMade_my_player_2    0.005811
# 162                    seconds_opposing_player_2    0.005779
# 143                      speed_opposing_player_1    0.005300
# 282                                     REF_BIAS    0.003653
# 287                                CLOSE_WIN_PCT    0.003389
# 291                               RECENT_WIN_PCT    0.002597
# 292                                     DISTANCE    0.002189
# 289                                    REST_DAYS    0.000858
# 288                              IS_BACK_TO_BACK    0.000151

# %%
# season23_24
rf23_24 = RandomForestRegressor(n_estimators=100, random_state=42)
rf23_24.fit(s23_24_X, s23_24_y)

feature_importances = rf23_24.feature_importances_
importance_df = get_feature_importance(s23_24_X.columns, feature_importances)

# %%
top_30_features = set(importance_df.head(30)['Feature'])
filtered_df = filter_features_by_importance(importance_df, top_30_features)
filtered_df
# Out:
#                                          Feature  Importance
# 37               fieldGoalPercentage_my_player_2    0.078819
# 17               fieldGoalPercentage_my_player_1    0.067253
# 77               fieldGoalPercentage_my_player_4    0.061427
# 57               fieldGoalPercentage_my_player_3    0.048865
# 97               fieldGoalPercentage_my_player_5    0.025233
# 117              fieldGoalPercentage_my_player_6    0.022338
# 16   uncontestedFieldGoalsPercentage_my_player_1    0.017601
# 14         uncontestedFieldGoalsMade_my_player_1    0.013409
# 137              fieldGoalPercentage_my_player_7    0.012749
# 3                           distance_my_player_1    0.011042
# 96   uncontestedFieldGoalsPercentage_my_player_5    0.010140
# 163                   distance_opposing_player_2    0.009508
# 56   uncontestedFieldGoalsPercentage_my_player_3    0.009118
# 292                             OPPONENT_WIN_PCT    0.008980
# 54         uncontestedFieldGoalsMade_my_player_3    0.008536
# 10                           assists_my_player_1    0.007812
# 76   uncontestedFieldGoalsPercentage_my_player_4    0.007653
# 183                   distance_opposing_player_3    0.007354
# 291                               RECENT_WIN_PCT    0.007258
# 43                          distance_my_player_3    0.006876
# 203                   distance_opposing_player_4    0.006431
# 222                      speed_opposing_player_5    0.006425
# 162                      speed_opposing_player_2    0.006363
# 143                   distance_opposing_player_1    0.005793
# 286                                      WIN_PCT    0.005547
# 142                      speed_opposing_player_1    0.005223
# 36   uncontestedFieldGoalsPercentage_my_player_2    0.005220
# 242                      speed_opposing_player_6    0.005213
# 182                      speed_opposing_player_3    0.005181
# 74         uncontestedFieldGoalsMade_my_player_4    0.005159
# 289                                    REST_DAYS    0.003647
# 282                                     REF_BIAS    0.003239
# 290                                     DISTANCE    0.003192
# 287                                CLOSE_WIN_PCT    0.002888
# 288                              IS_BACK_TO_BACK    0.000038

# %% [markdown]
# ### XGBoost regressor

# %%
# season22_23
xgb22_23 = xgb.XGBRegressor(n_estimators=100, random_state=42)
xgb22_23.fit(s22_23_X, s22_23_y)

feature_importances = xgb22_23.feature_importances_
importance_df = get_feature_importance(s22_23_X.columns, feature_importances)

# %%
top_30_features = set(importance_df.head(30)['Feature'])
filtered_df = filter_features_by_importance(importance_df, top_30_features)
filtered_df
# Out:
#                                                Feature  Importance
# 18                     fieldGoalPercentage_my_player_1    0.046796
# 38                     fieldGoalPercentage_my_player_2    0.027023
# 138                    fieldGoalPercentage_my_player_7    0.025815
# 58                     fieldGoalPercentage_my_player_3    0.022760
# 78                     fieldGoalPercentage_my_player_4    0.022692
# 98                     fieldGoalPercentage_my_player_5    0.020930
# 118                    fieldGoalPercentage_my_player_6    0.020805
# 169                 freeThrowAssists_opposing_player_2    0.020269
# 95               uncontestedFieldGoalsMade_my_player_5    0.019406
# 117        uncontestedFieldGoalsPercentage_my_player_6    0.018307
# 284                                              CLOSE    0.018221
# 77         uncontestedFieldGoalsPercentage_my_player_4    0.014776
# 142                          seconds_opposing_player_1    0.014068
# 279      defendedAtRimFieldGoalsMade_opposing_player_7    0.013786
# 135              uncontestedFieldGoalsMade_my_player_7    0.012739
# 261  defendedAtRimFieldGoalPercentage_opposing_play...    0.012725
# 184                         distance_opposing_player_3    0.012358
# 101       defendedAtRimFieldGoalPercentage_my_player_5    0.010619
# 204                         distance_opposing_player_4    0.010084
# 115              uncontestedFieldGoalsMade_my_player_6    0.009448
# 183                            speed_opposing_player_3    0.009162
# 163                            speed_opposing_player_2    0.009131
# 55               uncontestedFieldGoalsMade_my_player_3    0.008836
# 144                         distance_opposing_player_1    0.008724
# 139            defendedAtRimFieldGoalsMade_my_player_7    0.008084
# 37         uncontestedFieldGoalsPercentage_my_player_2    0.007941
# 232          contestedFieldGoalsMade_opposing_player_5    0.007666
# 51                                 assists_my_player_3    0.007523
# 91                                 assists_my_player_5    0.007333
# 140       defendedAtRimFieldGoalsAttempted_my_player_7    0.007015
# 289                                          REST_DAYS    0.002800
# 292                                           DISTANCE    0.001608
# 282                                           REF_BIAS    0.001351
# 287                                      CLOSE_WIN_PCT    0.001288
# 288                                    IS_BACK_TO_BACK    0.000213
# 291                                     RECENT_WIN_PCT    0.000000

# %%
# season23_24
xgb23_24 = xgb.XGBRegressor(n_estimators=100, random_state=42)
xgb23_24.fit(s23_24_X, s23_24_y)

feature_importances = xgb23_24.feature_importances_
importance_df = get_feature_importance(s23_24_X.columns, feature_importances)

# %%
top_30_features = set(importance_df.head(30)['Feature'])
filtered_df = filter_features_by_importance(importance_df, top_30_features)
filtered_df
# Out:
#                                             Feature  Importance
# 77                  fieldGoalPercentage_my_player_4    0.048408
# 37                  fieldGoalPercentage_my_player_2    0.042299
# 17                  fieldGoalPercentage_my_player_1    0.034087
# 57                  fieldGoalPercentage_my_player_3    0.028426
# 117                 fieldGoalPercentage_my_player_6    0.022160
# 97                  fieldGoalPercentage_my_player_5    0.021378
# 14            uncontestedFieldGoalsMade_my_player_1    0.020233
# 137                 fieldGoalPercentage_my_player_7    0.017881
# 54            uncontestedFieldGoalsMade_my_player_3    0.015118
# 284                                           CLOSE    0.014443
# 292                                OPPONENT_WIN_PCT    0.013902
# 198   defendedAtRimFieldGoalsMade_opposing_player_3    0.013867
# 34            uncontestedFieldGoalsMade_my_player_2    0.013309
# 74            uncontestedFieldGoalsMade_my_player_4    0.012719
# 16      uncontestedFieldGoalsPercentage_my_player_1    0.012535
# 113        contestedFieldGoalPercentage_my_player_6    0.012525
# 96      uncontestedFieldGoalsPercentage_my_player_5    0.012311
# 163                      distance_opposing_player_2    0.011284
# 10                              assists_my_player_1    0.011239
# 136     uncontestedFieldGoalsPercentage_my_player_7    0.011096
# 291                                  RECENT_WIN_PCT    0.010978
# 146                       touches_opposing_player_1    0.010348
# 111             contestedFieldGoalsMade_my_player_6    0.009547
# 76      uncontestedFieldGoalsPercentage_my_player_4    0.009202
# 116     uncontestedFieldGoalsPercentage_my_player_6    0.009116
# 183                      distance_opposing_player_3    0.008926
# 286                                         WIN_PCT    0.008629
# 134           uncontestedFieldGoalsMade_my_player_7    0.008352
# 213  contestedFieldGoalPercentage_opposing_player_4    0.008308
# 165           reboundChancesTotal_opposing_player_2    0.007992
# 290                                        DISTANCE    0.003175
# 282                                        REF_BIAS    0.002968
# 289                                       REST_DAYS    0.002041
# 287                                   CLOSE_WIN_PCT    0.001169
# 288                                 IS_BACK_TO_BACK    0.000000

# %% [markdown]
# ### Lasso Regression

# %%
# season22_23
lasso22_23 = Lasso(alpha=0.01)
lasso22_23.fit(s22_23_X, s22_23_y)

coef = lasso22_23.coef_
importance_df = get_feature_importance(s22_23_X.columns, coef)
# Out:
# /home/suyaozong/miniconda3/envs/nba_betting/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.575e+03, tolerance: 3.522e+01
#   model = cd_fast.enet_coordinate_descent(

# %%
top_30_features = set(importance_df.head(15)['Feature']) | set(importance_df.tail(15)['Feature'])
filtered_df = filter_features_by_importance(importance_df, top_30_features)
filtered_df
# Out:
#                                                Feature  Importance
# 18                     fieldGoalPercentage_my_player_1   10.703713
# 24                                distance_my_player_2    4.211129
# 158              fieldGoalPercentage_opposing_player_1    3.473680
# 184                         distance_opposing_player_3    2.913906
# 164                         distance_opposing_player_2    2.236538
# 64                                distance_my_player_4    2.050179
# 75               uncontestedFieldGoalsMade_my_player_4    1.953096
# 95               uncontestedFieldGoalsMade_my_player_5    1.944218
# 115              uncontestedFieldGoalsMade_my_player_6    1.835284
# 38                     fieldGoalPercentage_my_player_2    1.760110
# 135              uncontestedFieldGoalsMade_my_player_7    1.739812
# 132                contestedFieldGoalsMade_my_player_7    1.724944
# 55               uncontestedFieldGoalsMade_my_player_3    1.679162
# 98                     fieldGoalPercentage_my_player_5    1.599103
# 254     contestedFieldGoalPercentage_opposing_player_6    1.559815
# 291                                     RECENT_WIN_PCT    0.761998
# 289                                          REST_DAYS    0.031922
# 288                                    IS_BACK_TO_BACK    0.004155
# 292                                           DISTANCE   -0.000130
# 282                                           REF_BIAS   -0.070736
# 287                                      CLOSE_WIN_PCT   -0.649006
# 57         uncontestedFieldGoalsPercentage_my_player_3   -0.927309
# 174     contestedFieldGoalPercentage_opposing_player_2   -1.030333
# 161  defendedAtRimFieldGoalPercentage_opposing_play...   -1.123063
# 234     contestedFieldGoalPercentage_opposing_player_5   -1.154709
# 14            contestedFieldGoalPercentage_my_player_1   -1.205347
# 177  uncontestedFieldGoalsPercentage_opposing_player_2   -1.516265
# 77         uncontestedFieldGoalsPercentage_my_player_4   -1.650929
# 37         uncontestedFieldGoalsPercentage_my_player_2   -1.654991
# 198              fieldGoalPercentage_opposing_player_3   -2.077608
# 97         uncontestedFieldGoalsPercentage_my_player_5   -2.144804
# 63                                   speed_my_player_4   -2.619623
# 293                                   OPPONENT_WIN_PCT   -2.701059
# 23                                   speed_my_player_2   -2.884094
# 157  uncontestedFieldGoalsPercentage_opposing_player_1   -3.513045
# 17         uncontestedFieldGoalsPercentage_my_player_1   -5.233655

# %%
# season23_24
lasso23_24 = Lasso(alpha=0.01)
lasso23_24.fit(s23_24_X, s23_24_y)

coef = lasso23_24.coef_
importance_df = get_feature_importance(s23_24_X.columns, coef)
# Out:
# /home/suyaozong/miniconda3/envs/nba_betting/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.683e+03, tolerance: 4.058e+01
#   model = cd_fast.enet_coordinate_descent(

# %%
top_30_features = set(importance_df.head(15)['Feature']) | set(importance_df.tail(15)['Feature'])
filtered_df = filter_features_by_importance(importance_df, top_30_features)
filtered_df
# Out:
#                                                Feature  Importance
# 37                     fieldGoalPercentage_my_player_2    3.128156
# 291                                     RECENT_WIN_PCT    2.700272
# 54               uncontestedFieldGoalsMade_my_player_3    2.267065
# 14               uncontestedFieldGoalsMade_my_player_1    1.984862
# 97                     fieldGoalPercentage_my_player_5    1.842140
# 74               uncontestedFieldGoalsMade_my_player_4    1.822540
# 111                contestedFieldGoalsMade_my_player_6    1.706150
# 34               uncontestedFieldGoalsMade_my_player_2    1.604114
# 114              uncontestedFieldGoalsMade_my_player_6    1.572500
# 134              uncontestedFieldGoalsMade_my_player_7    1.458111
# 131                contestedFieldGoalsMade_my_player_7    1.408489
# 203                         distance_opposing_player_4    1.408113
# 22                                   speed_my_player_2    1.391720
# 284                                              CLOSE    1.385661
# 94               uncontestedFieldGoalsMade_my_player_5    1.379535
# 282                                           REF_BIAS    0.282881
# 290                                           DISTANCE    0.000104
# 288                                    IS_BACK_TO_BACK    0.000000
# 289                                          REST_DAYS   -0.012330
# 287                                      CLOSE_WIN_PCT   -0.435835
# 73            contestedFieldGoalPercentage_my_player_4   -0.875789
# 40        defendedAtRimFieldGoalPercentage_my_player_2   -0.892182
# 16         uncontestedFieldGoalsPercentage_my_player_1   -0.954318
# 180  defendedAtRimFieldGoalPercentage_opposing_play...   -0.975387
# 173     contestedFieldGoalPercentage_opposing_player_2   -1.096717
# 43                                distance_my_player_3   -1.150105
# 253     contestedFieldGoalPercentage_opposing_player_6   -1.192404
# 233     contestedFieldGoalPercentage_opposing_player_5   -1.201724
# 33            contestedFieldGoalPercentage_my_player_2   -1.301698
# 196  uncontestedFieldGoalsPercentage_opposing_player_3   -1.624801
# 23                                distance_my_player_2   -1.956429
# 3                                 distance_my_player_1   -2.189434
# 292                                   OPPONENT_WIN_PCT   -2.993889
# 156  uncontestedFieldGoalsPercentage_opposing_player_1   -3.492501
# 56         uncontestedFieldGoalsPercentage_my_player_3   -4.049911
